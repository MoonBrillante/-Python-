# %%
from urllib.request import urlopen
html=urlopen('http://pythonscraping.com/pages/page1.html')
print(html.read())
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('https://movie.douban.com/subject/3319755/')

soup = BeautifulSoup(html.read(),'lxml')

title = soup.find('h1').span.get_text()

daoyan = soup.find(id='info').find_all('span')[0].get_text()
date = soup.find(id='info').find_all('span')[16].get_text()


#print(soup.h1)
print(daoyan,date)
# Out:
# 导演: 罗伯·莱纳 2010-07-26(好莱坞首映)

# %%
import urllib.request as urlrequest
from bs4 import BeautifulSoup

douban_url= 'http://movie.douban.com/subject/3319775/'
page=urlrequest.urlopen(douban_url).read()
soup=BeautifulSoup(page,'html.parser')

title=soup.find('h1').span.get_text()
score=soup.find(class_="ll rating_num" ).get_text()
daoyan=soup.find(id='info').find_all('span')[0].get_text()
date=soup.find(id='info').find_all('span')[16].get_text()

print('{},{},{},{}'.format(title,score,daoyan,date))
# Out:
# 精彩的一天 멋진 하루,7.5,导演: 李胤基,片长:

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('http://pythonscraping.com/pages/page1.html')
bsobj=BeautifulSoup(html.read(),'lxml')
print(bsobj)

# %%
from urllib.request import urlopen
#from bs4 import BeautifulSoup

html = urlopen('https://movie.douban.com/tv/#!type=tv&tag=%E7%83%AD%E9%97%A8&sort=recommend&page_limit=20&page_start=0')
#bsobj = BeautifulSoup(html.read(),'lxml')
#categoryList = bsobj.findAll('class',{'class':'jd-category-div cur'})
soup=BeautifulSoup(html,'html.parser')

title=soup.findAll({'h1'})


print(title)
# Out:
# [<h1>热门电视剧</h1>]

# %%
from urllib.request import urlopen
html = urlopen('https://item.jd.com/6946605.html')

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html =urlopen("https://item.jd.com/6946605.html")
bsobj = BeautifulSoup(html.read(),'lxml')
print(bsobj)
# Out:
# <!DOCTYPE HTML>
# <html lang="zh-CN">
# <head>
# <!-- shouji -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>【华为P20】华为 HUAWEI P20 AI智慧徕卡双摄全面屏游戏手机 6GB+64GB 亮黑色 全网通移动联通电信4G手机 双卡双待【行情 报价 价格 评测】-京东</title>
# <meta content="HUAWEIP20,华为P20,华为P20报价,HUAWEIP20报价" name="keywords"/>
# <meta content="【华为P20】京东JD.COM提供华为P20正品行货，并包括HUAWEIP20网购指南，以及华为P20图片、P20参数、P20评论、P20心得、P20技巧等信息，网购华为P20上京东,放心又轻松" name="description"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="format=xhtml; url=//item.m.jd.com/product/6946605.html" http-equiv="mobile-agent"/>
# <meta content="format=html5; url=//item.m.jd.com/product/6946605.html" http-equiv="mobile-agent"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <link href="//item.jd.com/6946605.html" rel="canonical"/>
# <link href="//misc.360buyimg.com" rel="dns-prefetch"/>
# <link href="//static.360buyimg.com" rel="dns-prefetch"/>
# <link href="//img10.360buyimg.com" rel="dns-prefetch"/>
# ...
